# %%
word_list = "it was the best of times it was the worst of times"
word_list += "it was the age of wisdom it was the age of foolishness"

# %%
word_list = word_list.split()

# %%
print(word_list)
# Out:
# ['it', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'timesit', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness']

# %%
wordfreq = []

# %%
for word in word_list:
    wordfreq.append(word_list.count(word))

# %%
print(wordfreq)
# Out:
# [3, 4, 4, 1, 4, 1, 3, 4, 4, 1, 4, 1, 4, 4, 2, 4, 1, 3, 4, 4, 2, 4, 1]

# %%
print("pairs: "+ str(list(zip(word_list, wordfreq))))
# Out:
# pairs: [('it', 3), ('was', 4), ('the', 4), ('best', 1), ('of', 4), ('times', 1), ('it', 3), ('was', 4), ('the', 4), ('worst', 1), ('of', 4), ('timesit', 1), ('was', 4), ('the', 4), ('age', 2), ('of', 4), ('wisdom', 1), ('it', 3), ('was', 4), ('the', 4), ('age', 2), ('of', 4), ('foolishness', 1)]

# %%
#alternative method 
word_freq = [word_list.count(w) for w in word_list]

# %%
print(word_freq)
# Out:
# [3, 4, 4, 1, 4, 1, 3, 4, 4, 1, 4, 1, 4, 4, 2, 4, 1, 3, 4, 4, 2, 4, 1]

# %%
#dictionary 
s = "hello world"
print (s[0])
# Out:
# h

# %%
s = s.split()
print(s[0])
# Out:
# hello

# %%
print(s[0][0])
# Out:
# h

# %%
dictionary = {"world":1, "hello":0}
print(dictionary["hello"])
# Out:
# 0

# %%
print(dictionary.keys())
# Out:
# dict_keys(['world', 'hello'])

# %%
def wordListToFreqDict(word_list):
    word_freq = [word_list.count(p) for p in word_list]
    return dict(zip(word_list, word_freq))

# %%
def stripTags(words):
    inside =0
    text = ""
    for char in words:
        if char == '<':
            inside = 1
            continue
        elif (inside == 1 and char == '>'):
            inside = 0
            continue
        elif inside == 1:
            continue
        else:
            char = str(char)
            text += char
    return text

# %%
def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

# %%
import urllib.request, urllib.error

url = 'http://www.oldbaileyonline.org/browse.jsp?id=t17800628-33&div=t17800628-33'

response = urllib.request.urlopen(url)
html = response.read()
text = stripTags(html).lower()
dictionary = wordListToFreqDict(word_list)
sorteddict = sortFreqDict(dictionary)

for s in sorteddict: print(str(s))
# Out:
# (4, 'was')
# (4, 'the')
# (4, 'of')
# (3, 'it')
# (2, 'age')
# (1, 'worst')
# (1, 'wisdom')
# (1, 'timesit')
# (1, 'times')
# (1, 'foolishness')
# (1, 'best')

# %%
! pip install dh
# Out:
# Requirement already satisfied: dh in /Users/alicia/miniconda3/lib/python3.11/site-packages (0.15.3)

# %%
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
stopwords += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
stopwords += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
stopwords += ['some', 'somehow', 'someone', 'something', 'sometime']
stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
stopwords += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
stopwords += ['whatever', 'when', 'whence', 'whenever', 'where']
stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
stopwords += ['within', 'without', 'would', 'yet', 'you', 'your']
stopwords += ['yours', 'yourself', 'yourselves']

# %%
def removeStopWords(wordlist, stopwrods):
    return [w for w in wordlist if w not in stopwords]

# %%
def stripNonAlphaNum(text):
    import re
    return re.compile(r'\W+', re.UNICODE).split(text)

# %%
import urllib.request, urllib.error, urllib.parse

url = 'http://www.oldbaileyonline.org/browse.jsp?id=t17800628-33&div=t17800628-33'

response = urllib.request.urlopen(url)
html = response.read().decode('UTF-8')
text = stripTags(html).lower()
fullwordlist = stripNonAlphaNum(text)
wordlist = removeStopWords(fullwordlist, stopwords)
dictionary = wordListToFreqDict(wordlist)
sorteddict = sortFreqDict(dictionary)

for s in sorteddict: print(str(s))
# Out:
# (25, 'house')
# (20, 'yes')
# (20, 'prisoner')
# (19, 'mr')
# (17, 'man')
# (15, 'akerman')
# (14, 'mob')
# (13, 'black')
# (12, 'night')
# (11, 'saw')
# (10, 'window')
# (9, 'went')
# (9, 'sworn')
# (9, 'room')
# (9, 'pair')
# (9, 'know')
# (9, 'june')
# (9, 'face')
# (8, 'time')
# (8, 'thing')
# (8, 'believe')
# (7, 'took')
# (7, 'swear')
# (7, 'stairs')
# (7, 'servant')
# (7, 'lodging')
# (7, 'lie')
# (7, 'key')
# (7, 'door')
# (6, 'lay')
# (6, 'hat')
# (6, 'came')
# (6, '6th')
# (5, 'stockings')
# (5, 'second')
# (5, 'say')
# (5, 'prison')
# (5, 'positive')
# (5, 'place')
# (5, 'person')
# (5, 'people')
# (5, 'particular')
# (5, 'open')
# (5, 'o')
# (5, 'knew')
# (5, 'hair')
# (5, 'goods')
# (5, 'clock')
# (4, 'week')
# (4, 'trunk')
# (4, 'times')
# (4, 'remark')
# (4, 'proceedings')
# (4, 'persons')
# (4, 'original')
# (4, 'notice')
# (4, 'home')
# (4, 'hands')
# (4, 'gave')
# (4, 'evening')
# (4, 'day')
# (4, 'certain')
# (4, 'burnt')
# (4, 'better')
# (3, 'years')
# (3, 'wood')
# (3, 'version')
# (3, 'trial')
# (3, 'till')
# (3, 'seven')
# (3, 'servants')
# (3, 'search')
# (3, 'rest')
# (3, 'remember')
# (3, 'remarkable')
# (3, 'parlour')
# (3, 'opposite')
# (3, 'old')
# (3, 'observed')
# (3, 'men')
# (3, 'master')
# (3, 'mark')
# (3, 'looking')
# (3, 'looked')
# (3, 'live')
# (3, 'little')
# (3, 'jury')
# (3, 'initials')
# (3, 'immediately')
# (3, 'hour')
# (3, 'head')
# (3, 'handkerchief')
# (3, 'hand')
# (3, 'gtag')
# (3, 'genteel')
# (3, 'form')
# (3, 'examination')
# (3, 'dressed')
# (3, 'doing')
# (3, 'date')
# (3, 'datalayer')
# (3, 'crown')
# (3, 'cross')
# (3, 'court')
# (3, 'counsel')
# (3, 'character')
# (3, 'bowsey')
# (3, 'benjamin')
# (3, 'bailey')
# (3, 'attacked')
# (3, 'ann')
# (3, '1674')
# (2, 'wove')
# (2, 'white')
# (2, 'washed')
# (2, 'voice')
# (2, 'view')
# (2, 'tuesday')
# (2, 'town')
# (2, 'throw')
# (2, 'thought')
# (2, 'thirty')
# (2, 'think')
# (2, 'text')
# (2, 'taken')
# (2, 'sure')
# (2, 'street')
# (2, 'sticks')
# (2, 'standing')
# (2, 'sleep')
# (2, 'situated')
# (2, 'shelf')
# (2, 'set')
# (2, 'section')
# (2, 'said')
# (2, 'round')
# (2, 'roberts')
# (2, 'richard')
# (2, 'push')
# (2, 'producing')
# (2, 'proceeded')
# (2, 'pocket')
# (2, 'phillips')
# (2, 'perfectly')
# (2, 'peace')
# (2, 'ordinary')
# (2, 'online')
# (2, 'navigation')
# (2, 'mind')
# (2, 'mattocks')
# (2, 'make')
# (2, 'main')
# (2, 'london')
# (2, 'lives')
# (2, 'lived')
# (2, 'light')
# (2, 'lessar')
# (2, 'legs')
# (2, 'left')
# (2, 'knowledge')
# (2, 'keys')
# (2, 'jennings')
# (2, 'inactive')
# (2, 'impression')
# (2, 'holbourn')
# (2, 'held')
# (2, 'heard')
# (2, 'having')
# (2, 'granted')
# (2, 'got')
# (2, 'good')
# (2, 'formidable')
# (2, 'forced')
# (2, 'dress')
# (2, 'drawers')
# (2, 'doubt')
# (2, 'divided')
# (2, 'distinguish')
# (2, 'difficulty')
# (2, 'design')
# (2, 'dark')
# (2, 'cut')
# (2, 'criminal')
# (2, 'course')
# (2, 'constable')
# (2, 'coming')
# (2, 'come')
# (2, 'colour')
# (2, 'coat')
# (2, 'circle')
# (2, 'central')
# (2, 'book')
# (2, 'bid')
# (2, 'bed')
# (2, 'bar')
# (2, 'b')
# (2, 'associated')
# (2, 'appearance')
# (2, 'amp')
# (2, 'ago')
# (2, 'adsbygoogle')
# (2, 'active')
# (2, 'accounts')
# (2, 'account')
# (2, '8')
# (2, '7th')
# (2, '2018')
# (2, '1834')
# (2, '0')
# (2, '')
# (1, 'xml')
# (1, 'www')
# (1, 'wvnyp9x0ff')
# (1, 'work')
# (1, 'woman')
# (1, 'witnesses')
# (1, 'windows')
# (1, 'wiki')
# (1, 'wife')
# (1, 'wheels')
# (1, 'welcome')
# (1, 'weight')
# (1, 'wednesday')
# (1, 'web')
# (1, 'way')
# (1, 'washerwoman')
# (1, 'wash')
# (1, 'waistcoat')
# (1, 'w')
# (1, 'visual')
# (1, 'used')
# (1, 'use')
# (1, 'unlawfully')
# (1, 'twice')
# (1, 'turned')
# (1, 'tumultuously')
# (1, 'truth')
# (1, 'tried')
# (1, 'tough')
# (1, 'told')
# (1, 'tied')
# (1, 'thursday')
# (1, 'thrown')
# (1, 'throwing')
# (1, 'threw')
# (1, 'things')
# (1, 'textold')
# (1, 'tell')
# (1, 'technical')
# (1, 'talk')
# (1, 't17800628')
# (1, 'suppose')
# (1, 'struck')
# (1, 'stood')
# (1, 'steps')
# (1, 'statute')
# (1, 'statistics')
# (1, 'station')
# (1, 'square')
# (1, 'spokes')
# (1, 'spoke')
# (1, 'smooth')
# (1, 'smithfield')
# (1, 'sitemap')
# (1, 'site')
# (1, 'sister')
# (1, 'silk')
# (1, 'sight')
# (1, 'shutters')
# (1, 'showers')
# (1, 'shoulders')
# (1, 'self')
# (1, 'seen')
# (1, 'seeing')
# (1, 'searched')
# (1, 'saving')
# (1, 'sandiman')
# (1, 'sailor')
# (1, 'running')
# (1, 'rose')
# (1, 'roof')
# (1, 'robert')
# (1, 'riotously')
# (1, 'riot')
# (1, 'retired')
# (1, 'report')
# (1, 'remarks')
# (1, 'relation')
# (1, 'register')
# (1, 'red')
# (1, 'recordsactionscite')
# (1, 'records')
# (1, 'recollection')
# (1, 'recollect')
# (1, 'rapped')
# (1, 'quite')
# (1, 'quarter')
# (1, 'pulling')
# (1, 'pulled')
# (1, 'pull')
# (1, 'public')
# (1, 'projectuser')
# (1, 'proceedingshistorical')
# (1, 'print')
# (1, 'previous')
# (1, 'prevent')
# (1, 'precisely')
# (1, 'preceded')
# (1, 'possession')
# (1, 'pointed')
# (1, 'personal')
# (1, 'percival')
# (1, 'paving')
# (1, 'party')
# (1, 'partly')
# (1, 'particularly')
# (1, 'park')
# (1, 'outside')
# (1, 'originalhis')
# (1, 'org')
# (1, 'order')
# (1, 'opportunity')
# (1, 'opened')
# (1, 'oldbaileyonline')
# (1, 'october')
# (1, 'occasion')
# (1, 'observation')
# (1, 'obeisance')
# (1, 'numbert17800628')
# (1, 'number')
# (1, 'notwith')
# (1, 'northington')
# (1, 'nodded')
# (1, 'newgate')
# (1, 'new')
# (1, 'neck')
# (1, 'near')
# (1, 'navigationjump')
# (1, 'navigationhomesearchabout')
# (1, 'nares')
# (1, 'mysee')
# (1, 'mud')
# (1, 'moved')
# (1, 'motley')
# (1, 'morning')
# (1, 'middle')
# (1, 'mentioned')
# (1, 'meddle')
# (1, 'meaning')
# (1, 'material')
# (1, 'married')
# (1, 'marks')
# (1, 'marked')
# (1, 'march')
# (1, 'map')
# (1, 'manner')
# (1, 'making')
# (1, 'makes')
# (1, 'maker')
# (1, 'lt')
# (1, 'lord')
# (1, 'look')
# (1, 'long')
# (1, 'login')
# (1, 'lodged')
# (1, 'lodge')
# (1, 'locked')
# (1, 'let')
# (1, 'length')
# (1, 'leave')
# (1, 'langdale')
# (1, 'landlady')
# (1, 'lady')
# (1, 'known')
# (1, 'kindled')
# (1, 'kind')
# (1, 'justice')
# (1, 'jump')
# (1, 'judiciously')
# (1, 'js')
# (1, 'john')
# (1, 'jacket')
# (1, 'iron')
# (1, 'innumerable')
# (1, 'innocent')
# (1, 'indignation')
# (1, 'indicted')
# (1, 'houses')
# (1, 'helped')
# (1, 'heels')
# (1, 'happened')
# (1, 'handkerchiefs')
# (1, 'hall')
# (1, 'ha')
# (1, 'guilty')
# (1, 'guide')
# (1, 'gt')
# (1, 'ground')
# (1, 'grace')
# (1, 'goodhousen')
# (1, 'golden')
# (1, 'gingling')
# (1, 'genteeler')
# (1, 'gates')
# (1, 'g')
# (1, 'furniture')
# (1, 'function')
# (1, 'friendly')
# (1, 'forwards')
# (1, 'force')
# (1, 'footman')
# (1, 'footer')
# (1, 'following')
# (1, 'followed')
# (1, 'floor')
# (1, 'felons')
# (1, 'fellow')
# (1, 'feedback')
# (1, 'family')
# (1, 'fallen')
# (1, 'extreme')
# (1, 'exposed')
# (1, 'exhibit')
# (1, 'exciting')
# (1, 'excited')
# (1, 'excellent')
# (1, 'exceedingly')
# (1, 'exceeding')
# (1, 'esq')
# (1, 'errornavigation')
# (1, 'err')
# (1, 'equal')
# (1, 'england')
# (1, 'endeavoured')
# (1, 'encouraging')
# (1, 'dwelling')
# (1, 'drawer')
# (1, 'dr')
# (1, 'disturbance')
# (1, 'distinction')
# (1, 'dining')
# (1, 'dined')
# (1, 'difficult')
# (1, 'details')
# (1, 'destroying')
# (1, 'destroyed')
# (1, 'destroy')
# (1, 'desire')
# (1, 'description')
# (1, 'demonstrator')
# (1, 'demolished')
# (1, 'demolish')
# (1, 'degree')
# (1, 'defence')
# (1, 'debtor')
# (1, 'death')
# (1, 'danger')
# (1, 'custom')
# (1, 'curls')
# (1, 'crows')
# (1, 'crew')
# (1, 'copyright')
# (1, 'copy')
# (1, 'continued')
# (1, 'contentjump')
# (1, 'contact')
# (1, 'conflagration')
# (1, 'config')
# (1, 'confess')
# (1, 'conduct')
# (1, 'company')
# (1, 'coach')
# (1, 'close')
# (1, 'citation')
# (1, 'chissels')
# (1, 'cheques')
# (1, 'catching')
# (1, 'catched')
# (1, 'carry')
# (1, 'candle')
# (1, 'c')
# (1, 'burning')
# (1, 'burn')
# (1, 'bundle')
# (1, 'browse')
# (1, 'brownish')
# (1, 'brown')
# (1, 'brother')
# (1, 'broke')
# (1, 'bringing')
# (1, 'bring')
# (1, 'brewers')
# (1, 'breast')
# (1, 'breaking')
# (1, 'box')
# (1, 'borne')
# (1, 'bore')
# (1, 'body')
# (1, 'blue')
# (1, 'bludgeons')
# (1, 'blacks')
# (1, 'blackmoor')
# (1, 'berner')
# (1, 'belonging')
# (1, 'bell')
# (1, 'begin')
# (1, 'bb')
# (1, 'barrocadoed')
# (1, 'banker')
# (1, 'backwards')
# (1, 'backgrounddatathe')
# (1, 'assemble')
# (1, 'ask')
# (1, 'arguments')
# (1, 'approached')
# (1, 'applied')
# (1, 'api')
# (1, 'america')
# (1, 'activity')
# (1, 'acquaintance')
# (1, 'able')
# (1, '8th')
# (1, '33verdictguiltysentencedeathrelated')
# (1, '33')
# (1, '324')
# (1, '3')
# (1, '28th')
# (1, '24')
# (1, '2023')
# (1, '2003')
# (1, '1913')
# (1, '1780reference')
# (1, '1780')
# (1, '1772')
# (1, '1676')
# (1, '160')
